# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import random
import gymnasium as gym
from mountain.envs.mountain import MountainEnv

# %%
# Load trajectories from pickle file
with open("trajectories.pickle", "rb") as f:
    trajectories = pickle.load(f)

# %%
def set_seed(seed=42):
    """
    Sets the random seed for NumPy, Python, and Gym for reproducibility.
    """
    np.random.seed(seed)
    random.seed(seed)

# %%
# Monte Carlo evaluation for vπ(s)
def mc_value_function(trajectories, gamma=0.9):
    returns = defaultdict(list)
    V = {}

    for episode in trajectories:
        G = 0
        visited_states = set()
        for t in reversed(range(len(episode))):
            state, action, reward, next_state = episode[t]
            G = gamma * G + reward
            if state not in visited_states:
                returns[state].append(G)
                visited_states.add(state)

    for state in returns:
        V[state] = np.mean(returns[state])

    return V

# %%
# Monte Carlo evaluation for qπ(a, s)
def mc_action_value_function(trajectories, gamma=0.9):
    returns = defaultdict(lambda: defaultdict(list))
    Q = defaultdict(lambda: defaultdict(float))

    for episode in trajectories:
        G = 0
        visited_state_actions = set()
        for t in reversed(range(len(episode))):
            state, action, reward, next_state = episode[t]
            G = gamma * G + reward
            if (state, action) not in visited_state_actions:
                returns[state][action].append(G)
                visited_state_actions.add((state, action))

    for state in returns:
        for action in returns[state]:
            Q[state][action] = np.mean(returns[state][action])

    return Q

# %%
# Compute the value functions
V_pi = mc_value_function(trajectories)
Q_pi = mc_action_value_function(trajectories)

# %%
# Convert V_pi to a grid representation
grid_height = 31
grid_width = 100
V_grid = np.zeros((grid_height, grid_width))

for state, value in V_pi.items():
    row, col = state
    V_grid[row, col] = value

# Plot the state-value function vπ(s)
plt.figure(figsize=(12, 6))
plt.imshow(V_grid, cmap='coolwarm', origin='upper')
plt.colorbar(label="Value")
plt.title("State-Value Function vπ(s)")
plt.xlabel("Column (X-axis)")
plt.ylabel("Row (Y-axis)")
plt.show()

# %%
# Monte Carlo Policy Improvement: Extract the greedy policy
def mc_policy_improvement(Q):
    policy = {}

    for state in Q:
        # Choose the action with the highest value
        policy[state] = max(Q[state], key=Q[state].get)

    return policy

# %%
# Improve the policy
pi_prime = mc_policy_improvement(Q_pi)

# %%
# Compare the new policy with the old one
def is_policy_optimal(Q, pi_prime):
    for state in Q:
        best_action = max(Q[state], key=Q[state].get)
        if pi_prime[state] != best_action:
            return False  # Policy can still be improved
    return True

# %%
# Check if the policy is optimal
optimal = is_policy_optimal(Q_pi, pi_prime)
print(f"Is the improved policy optimal? {'Yes' if optimal else 'No'}")
# Out:
# Is the improved policy optimal? Yes

# %%
# Count how many states had a policy change
policy_changes = sum(1 for s in pi_prime if pi_prime[s] != max(Q_pi[s], key=Q_pi[s].get))
print(f"Number of states where policy changed: {policy_changes}")
# Out:
# Number of states where policy changed: 0

# %% [markdown]
# ## 5 commenting on results
#
# **MC Evaluation Result**
# * The value function heatmap remained consistent with the terrain structure, indicating that the robot's movement was well-aligned with terrain difficulty.
#
# **MC Policy Improvement Results**
# * After applying MC policy improvement,
# * This suggests that the SpaceY trajectories were generated using a well-optimized policy, meaning further policy improvements were unnecessary.
#
# **Are All Trajectories Equally Useful for MC Evaluation and Improvement?**
# No, not all trajectories are equally useful. Here’s why:
# 1. Some Trajectories Provide More Information
#     * Good trajectories (those that follow high-reward paths) are valuable because they reinforce optimal policy decisions.
#     * Exploratory or suboptimal trajectories may not contribute much if they rarely visit useful states.
# 2. Coverage of the State Space
#     * If some states are rarely visited in the given trajectories, their value estimates will be unreliable.
#     * Monte Carlo methods rely on many visits to different states to get accurate estimates.
#     * If trajectories don’t cover all important states, some parts of the value function may be inaccurate.
# 3. Finite Trajectories
#     * Since the robot’s battery limits the number of steps, all trajectories are finite.
#     * Some states might not be evaluated with long-term returns because episodes end early.

# %% [markdown]
# ## 6 MC Control

# %%
# Environment dimensions
STATE_SPACE = (31, 100)  # 31 rows, 100 columns
ACTION_SPACE = 5  # 5 possible actions

# %%
def mc_control(env, gamma=0.9, episodes=20000, epsilon=0.2, alpha=0.1, threshold=0.1, policy=None):
    """
    Monte Carlo Control with Epsilon-Greedy, First-Visit MC, and Convergence Monitoring.

    Args:
        env: Gym environment instance.
        gamma: Discount factor.
        episodes: Number of episodes for evaluation.
        epsilon: Exploration rate.
        alpha: Learning rate for Q-value updates.
        threshold: Convergence threshold for policy stability.

    Returns:
        Optimal policy and action-value function.
    """
    set_seed(42)

    env.action_space.seed(42)  # Ensure Gym uses the same random seed
    env.reset(seed=42)  # Reset environment with seed

    Q = defaultdict(float)  # Q-values stored as Q[(state, action)]
    if policy is None:
        policy = defaultdict(lambda: np.random.choice(env.action_space.n))  # Default random policy
    last_policy = {}
    total_rewards = []
    average_rewards = []

    for episode in range(1, episodes + 1):
        # Reset environment and get initial state
        observation, _ = env.reset()
        state = tuple(observation['agent']['pos']) if isinstance(observation, dict) else tuple(observation)

        episode_data = []
        done = False
        total_reward = 0

        # Generate an episode by interacting with the environment
        while not done:
            # Epsilon-greedy action selection
            action = policy[state] if np.random.rand() > epsilon else np.random.choice(env.action_space.n)

            # Step through the environment
            next_obs, reward, done, _, _ = env.step(action)
            next_state = tuple(next_obs['agent']['pos']) if isinstance(next_obs, dict) else tuple(next_obs)

            # Store transition
            episode_data.append((state, action, reward))
            state = next_state
            total_reward += reward

        # First-Visit MC Evaluation: Compute Returns
        G = 0
        visited = set()

        for state, action, reward in reversed(episode_data):
            G = reward + gamma * G

            # First-visit check
            if (state, action) not in visited:
                Q[(state, action)] += alpha * (G - Q[(state, action)])
                visited.add((state, action))

        # Policy Improvement Step (Epsilon-Greedy)
        current_policy = {}
        for state, _, _ in episode_data:
            actions = [Q.get((state, a), 0) for a in range(env.action_space.n)]
            best_action = np.argmax(actions)
            current_policy[state] = best_action
            policy[state] = best_action

        total_rewards.append(total_reward)

        # Convergence Check Every 100 Episodes
        if episode % 100 == 0:
            policy_changes = sum(1 for s in current_policy if current_policy[s] != last_policy.get(s, None))
            avg_reward = np.mean(total_rewards[-100:])
            average_rewards.append(avg_reward)
            print(f"Episode {episode}: Epsilon = {epsilon:.4f}, Policy Changes = {policy_changes}, Avg Reward = {avg_reward:.2f}")

            # Stop early if policy stabilizes
            if policy_changes / max(1, len(current_policy)) < threshold:
                print(f"\n Converged after {episode} episodes with {policy_changes} changes!")
                break

        last_policy = current_policy
        epsilon = max(0.01, 0.2 * (0.999 ** episode))  # Slower epsilon decay

    print(f"\n Final Epsilon: {epsilon}")
    print(f"Average Reward over last 500 episodes: {np.mean(total_rewards[500:]):.2f}")
    print(f"Parameters: gamma={gamma}, episodes={episodes}, epsilon={epsilon}, alpha={alpha}, threshold={threshold}")

    return policy, Q, average_rewards

# %%
set_seed(42)

env = MountainEnv()

# Run Monte Carlo Control
policy_env1, Q_env1, avg_rewards_env1 = mc_control(env, episodes=20000, threshold=0.1, policy=None)
# Out:
# Episode 100: Epsilon = 0.1811, Policy Changes = 159, Avg Reward = -90.24
# Episode 200: Epsilon = 0.1639, Policy Changes = 143, Avg Reward = -86.02
# Episode 300: Epsilon = 0.1483, Policy Changes = 122, Avg Reward = -85.31
# Episode 400: Epsilon = 0.1342, Policy Changes = 142, Avg Reward = -85.69
# Episode 500: Epsilon = 0.1214, Policy Changes = 118, Avg Reward = -76.63
# Episode 600: Epsilon = 0.1098, Policy Changes = 110, Avg Reward = -70.60
# Episode 700: Epsilon = 0.0994, Policy Changes = 67, Avg Reward = -53.80
# Episode 800: Epsilon = 0.0899, Policy Changes = 66, Avg Reward = -45.17
# Episode 900: Epsilon = 0.0814, Policy Changes = 41, Avg Reward = -40.40
# Episode 1000: Epsilon = 0.0736, Policy Changes = 43, Avg Reward = -37.65
# Episode 1100: Epsilon = 0.0666, Policy Changes = 27, Avg Reward = -35.94
# Episode 1200: Epsilon = 0.0603, Policy Changes = 41, Avg Reward = -34.50
# Episode 1300: Epsilon = 0.0545, Policy Changes = 28, Avg Reward = -33.50
# Episode 1400: Epsilon = 0.0493, Policy Changes = 32, Avg Reward = -34.95
# Episode 1500: Epsilon = 0.0446, Policy Changes = 28, Avg Reward = -32.99
# Episode 1600: Epsilon = 0.0404, Policy Changes = 28, Avg Reward = -33.22
# Episode 1700: Epsilon = 0.0365, Policy Changes = 28, Avg Reward = -31.47
# Episode 1800: Epsilon = 0.0331, Policy Changes = 35, Avg Reward = -32.33
# Episode 1900: Epsilon = 0.0299, Policy Changes = 23, Avg Reward = -31.76
# Episode 2000: Epsilon = 0.0271, Policy Changes = 16, Avg Reward = -34.71
# Episode 2100: Epsilon = 0.0245, Policy Changes = 27, Avg Reward = -35.67
# Episode 2200: Epsilon = 0.0222, Policy Changes = 44, Avg Reward = -37.59
# Episode 2300: Epsilon = 0.0200, Policy Changes = 31, Avg Reward = -35.30
# Episode 2400: Epsilon = 0.0181, Policy Changes = 31, Avg Reward = -36.65
# Episode 2500: Epsilon = 0.0164, Policy Changes = 18, Avg Reward = -35.97
# Episode 2600: Epsilon = 0.0149, Policy Changes = 19, Avg Reward = -37.16
# Episode 2700: Epsilon = 0.0134, Policy Changes = 13, Avg Reward = -34.14
#
#  Converged after 2700 episodes with 13 changes!
#
#  Final Epsilon: 0.013436393606076444
# Average Reward over last 500 episodes: -37.98
# Parameters: gamma=0.9, episodes=20000, epsilon=0.013436393606076444, alpha=0.1, threshold=0.1

# %%
# Compare two policies to check how many states changed
def compare_policies(old_policy, new_policy):
    """
    Compare old and new policies to count how many states changed their action.
    """
    changes = np.sum(old_policy != new_policy)  # NumPy comparison
    return changes

# Compare the updated policy with the previous one
policy_changes = compare_policies(policy_env1, np.random.randint(ACTION_SPACE, size=STATE_SPACE))  # Random baseline for now
print(f"Number of states where policy changed after MC Control: {policy_changes}")
# Out:
# Number of states where policy changed after MC Control: 3100

# %%
env2 = gym.make('mountain/GridWorld-v2')
# Run Monte Carlo Control (env2)
policy_env2, Q_env2, avg_rewards_env2 = mc_control(env2, episodes=20000, threshold=0.1)
# Out:
# Episode 100: Epsilon = 0.1811, Policy Changes = 104, Avg Reward = -165.23
# Episode 200: Epsilon = 0.1639, Policy Changes = 26, Avg Reward = -171.37
# /opt/homebrew/anaconda3/envs/INF/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be int32, actual type: int64
#   logger.warn(
# /opt/homebrew/anaconda3/envs/INF/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /opt/homebrew/anaconda3/envs/INF/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be int32, actual type: int64
#   logger.warn(
# /opt/homebrew/anaconda3/envs/INF/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Episode 300: Epsilon = 0.1483, Policy Changes = 20, Avg Reward = -171.10
# Episode 400: Epsilon = 0.1342, Policy Changes = 23, Avg Reward = -170.75
# Episode 500: Epsilon = 0.1214, Policy Changes = 10, Avg Reward = -170.84
# Episode 600: Epsilon = 0.1098, Policy Changes = 24, Avg Reward = -173.20
# Episode 700: Epsilon = 0.0994, Policy Changes = 4, Avg Reward = -171.08
# Episode 800: Epsilon = 0.0899, Policy Changes = 20, Avg Reward = -167.91
# Episode 900: Epsilon = 0.0814, Policy Changes = 18, Avg Reward = -170.70
# Episode 1000: Epsilon = 0.0736, Policy Changes = 46, Avg Reward = -165.89
# Episode 1100: Epsilon = 0.0666, Policy Changes = 19, Avg Reward = -169.76
# Episode 1200: Epsilon = 0.0603, Policy Changes = 37, Avg Reward = -168.81
# Episode 1300: Epsilon = 0.0545, Policy Changes = 20, Avg Reward = -169.75
# Episode 1400: Epsilon = 0.0493, Policy Changes = 20, Avg Reward = -167.74
# Episode 1500: Epsilon = 0.0446, Policy Changes = 43, Avg Reward = -166.38
# Episode 1600: Epsilon = 0.0404, Policy Changes = 48, Avg Reward = -162.59
# Episode 1700: Epsilon = 0.0365, Policy Changes = 34, Avg Reward = -160.49
# Episode 1800: Epsilon = 0.0331, Policy Changes = 24, Avg Reward = -162.06
# Episode 1900: Epsilon = 0.0299, Policy Changes = 19, Avg Reward = -159.14
# Episode 2000: Epsilon = 0.0271, Policy Changes = 29, Avg Reward = -157.21
# Episode 2100: Epsilon = 0.0245, Policy Changes = 4, Avg Reward = -159.01
# Episode 2200: Epsilon = 0.0222, Policy Changes = 22, Avg Reward = -152.86
# Episode 2300: Epsilon = 0.0200, Policy Changes = 23, Avg Reward = -155.31
# Episode 2400: Epsilon = 0.0181, Policy Changes = 37, Avg Reward = -152.33
# Episode 2500: Epsilon = 0.0164, Policy Changes = 46, Avg Reward = -159.05
# Episode 2600: Epsilon = 0.0149, Policy Changes = 20, Avg Reward = -154.21
# Episode 2700: Epsilon = 0.0134, Policy Changes = 23, Avg Reward = -154.25
# Episode 2800: Epsilon = 0.0122, Policy Changes = 14, Avg Reward = -151.21
# Episode 2900: Epsilon = 0.0110, Policy Changes = 24, Avg Reward = -153.82
# Episode 3000: Epsilon = 0.0100, Policy Changes = 13, Avg Reward = -150.35
# Episode 3100: Epsilon = 0.0100, Policy Changes = 26, Avg Reward = -163.54
# Episode 3200: Epsilon = 0.0100, Policy Changes = 15, Avg Reward = -161.27
# Episode 3300: Epsilon = 0.0100, Policy Changes = 26, Avg Reward = -153.17
# Episode 3400: Epsilon = 0.0100, Policy Changes = 9, Avg Reward = -156.98
# Episode 3500: Epsilon = 0.0100, Policy Changes = 15, Avg Reward = -165.61
# Episode 3600: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -159.01
# Episode 3700: Epsilon = 0.0100, Policy Changes = 6, Avg Reward = -166.91
# Episode 3800: Epsilon = 0.0100, Policy Changes = 68, Avg Reward = -168.61
# Episode 3900: Epsilon = 0.0100, Policy Changes = 18, Avg Reward = -155.34
# Episode 4000: Epsilon = 0.0100, Policy Changes = 28, Avg Reward = -153.25
# Episode 4100: Epsilon = 0.0100, Policy Changes = 15, Avg Reward = -146.30
# Episode 4200: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -147.44
# Episode 4300: Epsilon = 0.0100, Policy Changes = 30, Avg Reward = -151.52
# Episode 4400: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -149.36
# Episode 4500: Epsilon = 0.0100, Policy Changes = 19, Avg Reward = -155.89
# Episode 4600: Epsilon = 0.0100, Policy Changes = 48, Avg Reward = -148.65
# Episode 4700: Epsilon = 0.0100, Policy Changes = 53, Avg Reward = -145.32
# Episode 4800: Epsilon = 0.0100, Policy Changes = 17, Avg Reward = -149.91
# Episode 4900: Epsilon = 0.0100, Policy Changes = 33, Avg Reward = -144.94
# Episode 5000: Epsilon = 0.0100, Policy Changes = 47, Avg Reward = -148.55
# Episode 5100: Epsilon = 0.0100, Policy Changes = 33, Avg Reward = -160.22
# Episode 5200: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -162.88
# Episode 5300: Epsilon = 0.0100, Policy Changes = 47, Avg Reward = -161.29
# Episode 5400: Epsilon = 0.0100, Policy Changes = 25, Avg Reward = -157.42
# Episode 5500: Epsilon = 0.0100, Policy Changes = 49, Avg Reward = -158.72
# Episode 5600: Epsilon = 0.0100, Policy Changes = 18, Avg Reward = -165.58
# Episode 5700: Epsilon = 0.0100, Policy Changes = 20, Avg Reward = -164.01
# Episode 5800: Epsilon = 0.0100, Policy Changes = 20, Avg Reward = -159.66
# Episode 5900: Epsilon = 0.0100, Policy Changes = 55, Avg Reward = -142.49
# Episode 6000: Epsilon = 0.0100, Policy Changes = 42, Avg Reward = -146.48
# Episode 6100: Epsilon = 0.0100, Policy Changes = 15, Avg Reward = -160.79
# Episode 6200: Epsilon = 0.0100, Policy Changes = 37, Avg Reward = -169.51
# Episode 6300: Epsilon = 0.0100, Policy Changes = 28, Avg Reward = -158.29
# Episode 6400: Epsilon = 0.0100, Policy Changes = 2, Avg Reward = -168.56
# Episode 6500: Epsilon = 0.0100, Policy Changes = 9, Avg Reward = -172.53
# Episode 6600: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -168.01
# Episode 6700: Epsilon = 0.0100, Policy Changes = 10, Avg Reward = -164.98
# Episode 6800: Epsilon = 0.0100, Policy Changes = 72, Avg Reward = -160.60
# Episode 6900: Epsilon = 0.0100, Policy Changes = 77, Avg Reward = -157.17
# Episode 7000: Epsilon = 0.0100, Policy Changes = 50, Avg Reward = -160.05
# Episode 7100: Epsilon = 0.0100, Policy Changes = 11, Avg Reward = -155.07
# Episode 7200: Epsilon = 0.0100, Policy Changes = 44, Avg Reward = -162.70
# Episode 7300: Epsilon = 0.0100, Policy Changes = 88, Avg Reward = -158.02
# Episode 7400: Epsilon = 0.0100, Policy Changes = 70, Avg Reward = -150.57
# Episode 7500: Epsilon = 0.0100, Policy Changes = 97, Avg Reward = -139.21
# Episode 7600: Epsilon = 0.0100, Policy Changes = 58, Avg Reward = -140.07
# Episode 7700: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -139.25
# Episode 7800: Epsilon = 0.0100, Policy Changes = 50, Avg Reward = -141.50
# Episode 7900: Epsilon = 0.0100, Policy Changes = 36, Avg Reward = -135.21
# Episode 8000: Epsilon = 0.0100, Policy Changes = 58, Avg Reward = -135.40
# Episode 8100: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -136.27
# Episode 8200: Epsilon = 0.0100, Policy Changes = 81, Avg Reward = -134.29
# Episode 8300: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -131.77
# Episode 8400: Epsilon = 0.0100, Policy Changes = 85, Avg Reward = -147.35
# Episode 8500: Epsilon = 0.0100, Policy Changes = 83, Avg Reward = -131.90
# Episode 8600: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -138.39
# Episode 8700: Epsilon = 0.0100, Policy Changes = 53, Avg Reward = -135.82
# Episode 8800: Epsilon = 0.0100, Policy Changes = 48, Avg Reward = -128.82
# Episode 8900: Epsilon = 0.0100, Policy Changes = 63, Avg Reward = -124.41
# Episode 9000: Epsilon = 0.0100, Policy Changes = 15, Avg Reward = -127.19
# Episode 9100: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -124.90
# Episode 9200: Epsilon = 0.0100, Policy Changes = 66, Avg Reward = -119.54
# Episode 9300: Epsilon = 0.0100, Policy Changes = 36, Avg Reward = -121.01
# Episode 9400: Epsilon = 0.0100, Policy Changes = 32, Avg Reward = -117.07
# Episode 9500: Epsilon = 0.0100, Policy Changes = 53, Avg Reward = -125.35
# Episode 9600: Epsilon = 0.0100, Policy Changes = 90, Avg Reward = -122.64
# Episode 9700: Epsilon = 0.0100, Policy Changes = 17, Avg Reward = -115.92
#
#  Converged after 9700 episodes with 17 changes!
#
#  Final Epsilon: 0.01
# Average Reward over last 500 episodes: -152.02
# Parameters: gamma=0.9, episodes=20000, epsilon=0.01, alpha=0.1, threshold=0.1

# %%
def visualize_optimal_path(env, policy, title="Optimal Path Over Mountain Environment"):
    """
    Simulates the trained policy and overlays the path on the terrain map.
    """
    state, _ = env.reset(seed=42)  # Reset environment for consistent visualization
    state = tuple(state['agent']['pos']) if isinstance(state, dict) else tuple(state)

    path = [state]  # Track path taken
    done = False

    while not done:
        action = policy[state]  # Follow trained policy
        next_obs, _, done, _, _ = env.step(action)
        state = tuple(next_obs['agent']['pos']) if isinstance(next_obs, dict) else tuple(next_obs)
        path.append(state)

    # Extract X, Y coordinates for path
    path_x = [p[1] for p in path]  # Columns
    path_y = [p[0] for p in path]  # Rows

    # FIX: Ensure each environment uses its own map
    plt.figure(figsize=(12, 6))
    plt.imshow(env.unwrapped.MAP, cmap='terrain', origin='upper')
    plt.colorbar(label='Elevation')
    plt.plot(path_x, path_y, marker='o', color='red', markersize=3, linestyle='-', linewidth=2, label="Optimal Path")
    plt.title(title)
    plt.legend()
    plt.show()

# %%
visualize_optimal_path(env, policy_env1, title="Optimal Path Over Mountain Environment (Env1)")

# %%
visualize_optimal_path(env2, policy_env2, title="Optimal Path Over Mountain Environment (Env2)")

# %%
env = MountainEnv()
plt.imshow(env.MAP, cmap='terrain')  # Change 'terrain' to another colormap if needed
plt.colorbar(label='Elevation')
plt.title("Mountain Environment Map")
plt.show()

# %% [markdown]
# ## 7 Starting policy
# **𝜖-Greedy Policy (𝜖 = 0.2)**
# * 80% of the time: Follow the best-known path (forward movement on smoother terrain).
# * 20% of the time: Explore alternative routes (to avoid getting stuck).
# * Why? This ensures both efficiency and adaptability
#
# **Prioritize Forward Movement (Action 0)**
# * Default action: Move right (toward the goal).
# * Why? Most efficient way to reach the end.
#
# **Allow Vertical Movement to Navigate Terrain**
# * If the next forward step leads to high elevation, allow up/down movement to find a better path.
#
# **Discourage Unnecessary Backtracking**
# * Penalty for backward movement (-0.5) to prevent looping.
# * Penalty for staying still (-1) to encourage continuous progress.

# %%
env1 = MountainEnv()
env2 = gym.make('mountain/GridWorld-v2')

# %%
def initialize_policy(env, epsilon=0.5):
    """
    Initializes an epsilon-greedy starting policy for the robot.
    Prioritizes forward movement but allows exploration.
    """
    policy = {}

    grid_height = 31  # Number of rows
    grid_width = 100  # Number of columns

    for row in range(grid_height):
        for col in range(grid_width):
            state = (row, col)  # Define state as (row, column)

            # Epsilon-greedy initialization
            if np.random.rand() > epsilon:
                policy[state] = 0  # Default to forward movement (Action 0)
            else:
                policy[state] = np.random.choice(env.action_space.n)  # Explore random action

    return policy

# %%
policy_env1 = initialize_policy(env1, epsilon=0.2)
policy_env2 = initialize_policy(env2, epsilon=0.2)

# %%
policy_env1, Q_env1, avg_rewards_env1 = mc_control(env1, episodes=20000, policy=policy_env1)
# Out:
# Episode 100: Epsilon = 0.1811, Policy Changes = 116, Avg Reward = -92.21
# Episode 200: Epsilon = 0.1639, Policy Changes = 142, Avg Reward = -85.61
# Episode 300: Epsilon = 0.1483, Policy Changes = 141, Avg Reward = -85.04
# Episode 400: Epsilon = 0.1342, Policy Changes = 71, Avg Reward = -84.63
# Episode 500: Epsilon = 0.1214, Policy Changes = 102, Avg Reward = -78.08
# Episode 600: Epsilon = 0.1098, Policy Changes = 93, Avg Reward = -66.40
# Episode 700: Epsilon = 0.0994, Policy Changes = 77, Avg Reward = -52.60
# Episode 800: Epsilon = 0.0899, Policy Changes = 89, Avg Reward = -47.33
# Episode 900: Epsilon = 0.0814, Policy Changes = 51, Avg Reward = -44.00
# Episode 1000: Epsilon = 0.0736, Policy Changes = 52, Avg Reward = -41.71
# Episode 1100: Epsilon = 0.0666, Policy Changes = 35, Avg Reward = -39.16
# Episode 1200: Epsilon = 0.0603, Policy Changes = 50, Avg Reward = -37.79
# Episode 1300: Epsilon = 0.0545, Policy Changes = 35, Avg Reward = -37.32
# Episode 1400: Epsilon = 0.0493, Policy Changes = 38, Avg Reward = -38.29
# Episode 1500: Epsilon = 0.0446, Policy Changes = 23, Avg Reward = -36.80
# Episode 1600: Epsilon = 0.0404, Policy Changes = 33, Avg Reward = -35.29
# Episode 1700: Epsilon = 0.0365, Policy Changes = 46, Avg Reward = -35.46
# Episode 1800: Epsilon = 0.0331, Policy Changes = 38, Avg Reward = -36.35
# Episode 1900: Epsilon = 0.0299, Policy Changes = 25, Avg Reward = -35.04
# Episode 2000: Epsilon = 0.0271, Policy Changes = 31, Avg Reward = -34.38
# Episode 2100: Epsilon = 0.0245, Policy Changes = 19, Avg Reward = -36.61
# Episode 2200: Epsilon = 0.0222, Policy Changes = 22, Avg Reward = -34.65
# Episode 2300: Epsilon = 0.0200, Policy Changes = 26, Avg Reward = -34.26
# Episode 2400: Epsilon = 0.0181, Policy Changes = 29, Avg Reward = -35.87
# Episode 2500: Epsilon = 0.0164, Policy Changes = 32, Avg Reward = -39.75
# Episode 2600: Epsilon = 0.0149, Policy Changes = 35, Avg Reward = -37.50
# Episode 2700: Epsilon = 0.0134, Policy Changes = 27, Avg Reward = -33.96
# Episode 2800: Epsilon = 0.0122, Policy Changes = 29, Avg Reward = -36.77
# Episode 2900: Epsilon = 0.0110, Policy Changes = 31, Avg Reward = -35.64
# Episode 3000: Epsilon = 0.0100, Policy Changes = 25, Avg Reward = -36.43
# Episode 3100: Epsilon = 0.0100, Policy Changes = 23, Avg Reward = -37.02
# Episode 3200: Epsilon = 0.0100, Policy Changes = 18, Avg Reward = -36.01
# Episode 3300: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -33.65
# Episode 3400: Epsilon = 0.0100, Policy Changes = 33, Avg Reward = -37.27
# Episode 3500: Epsilon = 0.0100, Policy Changes = 42, Avg Reward = -40.86
# Episode 3600: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -38.92
# Episode 3700: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -37.33
# Episode 3800: Epsilon = 0.0100, Policy Changes = 29, Avg Reward = -36.90
# Episode 3900: Epsilon = 0.0100, Policy Changes = 31, Avg Reward = -38.58
# Episode 4000: Epsilon = 0.0100, Policy Changes = 30, Avg Reward = -39.42
# Episode 4100: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -37.62
# Episode 4200: Epsilon = 0.0100, Policy Changes = 28, Avg Reward = -35.30
# Episode 4300: Epsilon = 0.0100, Policy Changes = 43, Avg Reward = -33.61
# Episode 4400: Epsilon = 0.0100, Policy Changes = 23, Avg Reward = -33.67
# Episode 4500: Epsilon = 0.0100, Policy Changes = 18, Avg Reward = -36.79
# Episode 4600: Epsilon = 0.0100, Policy Changes = 31, Avg Reward = -36.16
# Episode 4700: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -36.46
# Episode 4800: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -35.63
# Episode 4900: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -37.55
# Episode 5000: Epsilon = 0.0100, Policy Changes = 25, Avg Reward = -41.23
# Episode 5100: Epsilon = 0.0100, Policy Changes = 23, Avg Reward = -41.57
# Episode 5200: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -40.03
# Episode 5300: Epsilon = 0.0100, Policy Changes = 35, Avg Reward = -40.61
# Episode 5400: Epsilon = 0.0100, Policy Changes = 25, Avg Reward = -40.36
# Episode 5500: Epsilon = 0.0100, Policy Changes = 17, Avg Reward = -36.73
# Episode 5600: Epsilon = 0.0100, Policy Changes = 28, Avg Reward = -36.25
# Episode 5700: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -35.65
# Episode 5800: Epsilon = 0.0100, Policy Changes = 35, Avg Reward = -36.68
# Episode 5900: Epsilon = 0.0100, Policy Changes = 33, Avg Reward = -37.89
# Episode 6000: Epsilon = 0.0100, Policy Changes = 26, Avg Reward = -47.72
# Episode 6100: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -47.95
# Episode 6200: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -44.42
# Episode 6300: Epsilon = 0.0100, Policy Changes = 30, Avg Reward = -36.64
# Episode 6400: Epsilon = 0.0100, Policy Changes = 31, Avg Reward = -39.21
# Episode 6500: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -36.74
# Episode 6600: Epsilon = 0.0100, Policy Changes = 23, Avg Reward = -34.70
# Episode 6700: Epsilon = 0.0100, Policy Changes = 19, Avg Reward = -36.65
# Episode 6800: Epsilon = 0.0100, Policy Changes = 38, Avg Reward = -32.81
# Episode 6900: Epsilon = 0.0100, Policy Changes = 42, Avg Reward = -35.53
# Episode 7000: Epsilon = 0.0100, Policy Changes = 35, Avg Reward = -35.94
# Episode 7100: Epsilon = 0.0100, Policy Changes = 15, Avg Reward = -36.02
# Episode 7200: Epsilon = 0.0100, Policy Changes = 34, Avg Reward = -39.30
# Episode 7300: Epsilon = 0.0100, Policy Changes = 26, Avg Reward = -40.67
# Episode 7400: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -39.09
# Episode 7500: Epsilon = 0.0100, Policy Changes = 15, Avg Reward = -38.45
# Episode 7600: Epsilon = 0.0100, Policy Changes = 31, Avg Reward = -36.27
# Episode 7700: Epsilon = 0.0100, Policy Changes = 22, Avg Reward = -35.68
# Episode 7800: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -36.61
# Episode 7900: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -39.51
# Episode 8000: Epsilon = 0.0100, Policy Changes = 32, Avg Reward = -38.19
# Episode 8100: Epsilon = 0.0100, Policy Changes = 32, Avg Reward = -34.04
# Episode 8200: Epsilon = 0.0100, Policy Changes = 25, Avg Reward = -33.85
# Episode 8300: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -34.55
# Episode 8400: Epsilon = 0.0100, Policy Changes = 22, Avg Reward = -35.13
# Episode 8500: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -34.50
# Episode 8600: Epsilon = 0.0100, Policy Changes = 23, Avg Reward = -39.89
# Episode 8700: Epsilon = 0.0100, Policy Changes = 32, Avg Reward = -36.56
# Episode 8800: Epsilon = 0.0100, Policy Changes = 20, Avg Reward = -35.32
# Episode 8900: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -35.22
# Episode 9000: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -33.20
# Episode 9100: Epsilon = 0.0100, Policy Changes = 26, Avg Reward = -36.58
# Episode 9200: Epsilon = 0.0100, Policy Changes = 45, Avg Reward = -34.51
# Episode 9300: Epsilon = 0.0100, Policy Changes = 36, Avg Reward = -39.13
# Episode 9400: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -37.33
# Episode 9500: Epsilon = 0.0100, Policy Changes = 34, Avg Reward = -37.92
# Episode 9600: Epsilon = 0.0100, Policy Changes = 32, Avg Reward = -35.85
# Episode 9700: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -37.98
# Episode 9800: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -38.78
# Episode 9900: Epsilon = 0.0100, Policy Changes = 37, Avg Reward = -37.76
# Episode 10000: Epsilon = 0.0100, Policy Changes = 43, Avg Reward = -36.13
# Episode 10100: Epsilon = 0.0100, Policy Changes = 25, Avg Reward = -39.86
# Episode 10200: Epsilon = 0.0100, Policy Changes = 31, Avg Reward = -43.84
# Episode 10300: Epsilon = 0.0100, Policy Changes = 14, Avg Reward = -43.45
# Episode 10400: Epsilon = 0.0100, Policy Changes = 39, Avg Reward = -41.64
# Episode 10500: Epsilon = 0.0100, Policy Changes = 33, Avg Reward = -40.32
# Episode 10600: Epsilon = 0.0100, Policy Changes = 31, Avg Reward = -39.65
# Episode 10700: Epsilon = 0.0100, Policy Changes = 20, Avg Reward = -38.36
# Episode 10800: Epsilon = 0.0100, Policy Changes = 18, Avg Reward = -34.54
# Episode 10900: Epsilon = 0.0100, Policy Changes = 50, Avg Reward = -36.31
# Episode 11000: Epsilon = 0.0100, Policy Changes = 18, Avg Reward = -40.09
# Episode 11100: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -40.93
# Episode 11200: Epsilon = 0.0100, Policy Changes = 15, Avg Reward = -40.48
# Episode 11300: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -36.51
# Episode 11400: Epsilon = 0.0100, Policy Changes = 16, Avg Reward = -34.94
# Episode 11500: Epsilon = 0.0100, Policy Changes = 25, Avg Reward = -37.37
# Episode 11600: Epsilon = 0.0100, Policy Changes = 35, Avg Reward = -38.64
# Episode 11700: Epsilon = 0.0100, Policy Changes = 30, Avg Reward = -39.79
# Episode 11800: Epsilon = 0.0100, Policy Changes = 23, Avg Reward = -36.00
# Episode 11900: Epsilon = 0.0100, Policy Changes = 27, Avg Reward = -37.33
# Episode 12000: Epsilon = 0.0100, Policy Changes = 23, Avg Reward = -40.94
# Episode 12100: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -43.26
# Episode 12200: Epsilon = 0.0100, Policy Changes = 22, Avg Reward = -42.24
# Episode 12300: Epsilon = 0.0100, Policy Changes = 22, Avg Reward = -38.37
# Episode 12400: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -35.32
# Episode 12500: Epsilon = 0.0100, Policy Changes = 24, Avg Reward = -33.09
# Episode 12600: Epsilon = 0.0100, Policy Changes = 21, Avg Reward = -34.50
# Episode 12700: Epsilon = 0.0100, Policy Changes = 20, Avg Reward = -35.69
# Episode 12800: Epsilon = 0.0100, Policy Changes = 25, Avg Reward = -35.47
# Episode 12900: Epsilon = 0.0100, Policy Changes = 35, Avg Reward = -34.39
# Episode 13000: Epsilon = 0.0100, Policy Changes = 28, Avg Reward = -33.91
# Episode 13100: Epsilon = 0.0100, Policy Changes = 7, Avg Reward = -35.56
#
#  Converged after 13100 episodes with 7 changes!
#
#  Final Epsilon: 0.01
# Average Reward over last 500 episodes: -37.94
# Parameters: gamma=0.9, episodes=20000, epsilon=0.01, alpha=0.1, threshold=0.1

# %%
policy_env2, Q_env2, avg_rewards_env2 = mc_control(env2, episodes=20000, policy=policy_env2)
# Out:
# Episode 100: Epsilon = 0.1811, Policy Changes = 20, Avg Reward = -156.53
# Episode 200: Epsilon = 0.1639, Policy Changes = 41, Avg Reward = -172.35
# Episode 300: Epsilon = 0.1483, Policy Changes = 45, Avg Reward = -173.48
# Episode 400: Epsilon = 0.1342, Policy Changes = 19, Avg Reward = -169.89
# Episode 500: Epsilon = 0.1214, Policy Changes = 4, Avg Reward = -168.38
# Episode 600: Epsilon = 0.1098, Policy Changes = 17, Avg Reward = -173.04
# Episode 700: Epsilon = 0.0994, Policy Changes = 29, Avg Reward = -165.83
# Episode 800: Epsilon = 0.0899, Policy Changes = 42, Avg Reward = -165.07
# Episode 900: Epsilon = 0.0814, Policy Changes = 44, Avg Reward = -164.89
# Episode 1000: Epsilon = 0.0736, Policy Changes = 34, Avg Reward = -167.37
# Episode 1100: Epsilon = 0.0666, Policy Changes = 38, Avg Reward = -168.61
# Episode 1200: Epsilon = 0.0603, Policy Changes = 28, Avg Reward = -170.44
# Episode 1300: Epsilon = 0.0545, Policy Changes = 20, Avg Reward = -167.72
# Episode 1400: Epsilon = 0.0493, Policy Changes = 30, Avg Reward = -162.62
# Episode 1500: Epsilon = 0.0446, Policy Changes = 18, Avg Reward = -167.52
# Episode 1600: Epsilon = 0.0404, Policy Changes = 42, Avg Reward = -163.11
# Episode 1700: Epsilon = 0.0365, Policy Changes = 31, Avg Reward = -160.26
# Episode 1800: Epsilon = 0.0331, Policy Changes = 33, Avg Reward = -163.95
# Episode 1900: Epsilon = 0.0299, Policy Changes = 21, Avg Reward = -165.08
# Episode 2000: Epsilon = 0.0271, Policy Changes = 29, Avg Reward = -168.90
# Episode 2100: Epsilon = 0.0245, Policy Changes = 38, Avg Reward = -167.64
# Episode 2200: Epsilon = 0.0222, Policy Changes = 49, Avg Reward = -158.10
# Episode 2300: Epsilon = 0.0200, Policy Changes = 29, Avg Reward = -144.48
# Episode 2400: Epsilon = 0.0181, Policy Changes = 21, Avg Reward = -155.83
# Episode 2500: Epsilon = 0.0164, Policy Changes = 16, Avg Reward = -152.00
# Episode 2600: Epsilon = 0.0149, Policy Changes = 27, Avg Reward = -152.64
# Episode 2700: Epsilon = 0.0134, Policy Changes = 21, Avg Reward = -149.37
# Episode 2800: Epsilon = 0.0122, Policy Changes = 5, Avg Reward = -153.42
#
#  Converged after 2800 episodes with 5 changes!
#
#  Final Epsilon: 0.012157143420306816
# Average Reward over last 500 episodes: -162.08
# Parameters: gamma=0.9, episodes=20000, epsilon=0.012157143420306816, alpha=0.1, threshold=0.1

# %%
visualize_optimal_path(env1, policy_env1, title="Optimal Path Over Mountain Environment (Env1)")

# %%
visualize_optimal_path(env2, policy_env2, title="Optimal Path Over Mountain Environment (Env2)")

# %%
import numpy as np
import gymnasium as gym
from collections import defaultdict

# Convert state dictionary to a tuple of its array values
def process_state(state):
    return tuple(state["agent"]["pos"])

# SARSA(0) Algorithm
def sarsa_0(env, episodes=500, alpha=0.1, gamma=0.9, epsilon=0.1):
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    
    for episode in range(episodes):
        state, _ = env.reset()
        state = process_state(state)  # Convert state to tuple
        action = epsilon_greedy(Q, state, epsilon)
        done = False
        
        while not done:
            next_state, reward, terminated, truncated, _ = env.step(action)
            next_state = process_state(next_state)  # Convert next state to tuple
            next_action = epsilon_greedy(Q, next_state, epsilon)
            
            Q[state][action] += alpha * (reward + gamma * Q[next_state][next_action] - Q[state][action])
            
            state, action = next_state, next_action
            done = terminated or truncated
    
    return Q

# Epsilon-Greedy Policy
def epsilon_greedy(Q, state, epsilon):
    if np.random.rand() < epsilon:
        return np.random.choice(len(Q[state]))
    return np.argmax(Q[state])

env = gym.make('mountain/GridWorld-v1')
Q_sarsa_0 = sarsa_0(env)

# %%
import numpy as np
import gymnasium as gym
from collections import defaultdict

# Convert state dictionary to a tuple of its array values
def process_state(state):
    return tuple(state["agent"]["pos"])

# SARSA(0) Algorithm
def sarsa_0(env, episodes=1000, alpha=0.1, gamma=0.9, epsilon=0.1):
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    rewards_per_episode = []
    
    for episode in range(episodes):
        state, _ = env.reset()
        state = process_state(state)  # Convert state to tuple
        action = epsilon_greedy(Q, state, epsilon)
        done = False
        total_reward = 0
        
        while not done:
            next_state, reward, terminated, truncated, _ = env.step(action)
            next_state = process_state(next_state)  # Convert next state to tuple
            next_action = epsilon_greedy(Q, next_state, epsilon)
            
            Q[state][action] += alpha * (reward + gamma * Q[next_state][next_action] - Q[state][action])
            
            state, action = next_state, next_action
            total_reward += reward
            done = terminated or truncated
        
        rewards_per_episode.append(total_reward)
        
        if episode % 100 == 0:
            avg_reward = np.mean(rewards_per_episode[-100:])
            print(f"Episode {episode}: Average Reward: {avg_reward:.2f}")
    
    return Q

# Epsilon-Greedy Policy
def epsilon_greedy(Q, state, epsilon):
    if np.random.rand() < epsilon:
        return np.random.choice(len(Q[state]))
    return np.argmax(Q[state])

env = gym.make('mountain/GridWorld-v1')
Q_sarsa_0 = sarsa_0(env)
# Out:
# Episode 0: Average Reward: -48.63
# Episode 100: Average Reward: -72.68
# Episode 200: Average Reward: -62.38
# Episode 300: Average Reward: -61.33
# Episode 400: Average Reward: -59.89
# Episode 500: Average Reward: -60.97
# Episode 600: Average Reward: -60.92
# Episode 700: Average Reward: -60.58
# Episode 800: Average Reward: -60.49
# Episode 900: Average Reward: -59.98
